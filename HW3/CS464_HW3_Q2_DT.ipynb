# %% [markdown]
# <b><h1><center>CS 464</center></h1></b>
# <b><h1><center>Introduction to Machine Learning</center></h1></b>
# <b><h1><center>Spring 2021</center></h1></b>
# <b><h1><center>Homework 3</center></h1></b>
# <h4><center>Due: <b>10 May</b> (GMT+3)</center></h4>

# %% [markdown]
# ### Instructions
#
# <ul>
#     <li>
#     This homework contains both written and programming questions about neural networks and SVM. </li>
#     <li>
#     You are not required to provide answers for <b>Question 1</b> on this notebook. You may use any programming language you like. In either case, you are required to prepare a report for Question 1, named <b>Q1_report.pdf</b>, which contains your results, plots and discussion for Question 1 only.
#     </li>
#     <li>
#     You should implement <b>Question 2</b> on this notebook. Your plots should also be produced in this notebook. Each programming question has its own cell for your answer. You can implement your code directly in these cells, or you can call required functions which are defined in a different location for the given question.
#     </li>
#     <li>
#     For questions that you need to plot, your plot results have to be included in the cell output. For written questions, you may provide them either as comments in code cells or as seperate text cells.
#     </li>
#     <li>
#     For question 1, you are <b>ALLOWED</b> to use machine learning libraries for training SVM models.
#     </li>
#     <li>
#     For questions 2, you are <b>NOT ALLOWED</b> to use different libraries than given libraries in the code segments of this homework except for libraries included in Python Standard Library (https://docs.python.org/3/library/).
#     </li>
#     <li>
#     You are <b>NOT ALLOWED</b> to use a different deep learning framework than PyTorch.
#     </li>
#     <li>
#     <b>IMPORTANT:</b> If you are asked to discuss your results add a new text cell right after you provide your results. On the other hand, if you are asked to provide a written answer for a question add a text cell under the description of the corresponding question.
#     </li>
#     <li>
#     While submitting the homework file, please package notebook(".ipynb") and model (".pth") files as a gzipped TAR file or a ZIP file with the name cs464_hw3_section#_Firstname_Lastname. Please do not use any Turkish letters for any of your files including code files and model files. Upload your homework to Moodle.
#     </li>
#     <li>
#     This is an individual assignment for each student. That is, you are <b>NOT ALLOWED</b> to share your work with your classmates.</li>
#     <li>
#     If you do not follow the submission routes, deadlines and specifications, it will lead to a significant grade deduction.
#     </li>
#     <li>
#     If you have any questions regarding <b>question 1</b> you may send an email to <b>salman.mohammad@bilkent.edu.tr</b>.
#     </li>
#     <li>
#     If you have any questions regarding <b>question 2</b> you may send an email to <b>doruk.cakmakci@bilkent.edu.tr</b>.
#     </li>
# </ul>

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# This homework is prepared by using Google Colab which already has access to required libraries. However, if you are using your own local Jupyter or any other Python notebook editor, you may use both anaconda or pip to install PyTorch to your own computer.

# %% [markdown]
# ### Anaconda Installation
#
# <ul>
#     <li>Download anaconda from https://www.anaconda.com/download</li>
#     <li>Follow the instructions provided in https://conda.io/docs/user-guide/install/index.html#regular-installation</li>
# </ul>
#
# #### Creation of Virtual Environment
#
# <ul>
#     <li>Create python3.7 virtual environment for your hw3 using follow command from the command line<br>
#         <i>> conda create -n HW3 python=3.7 anaconda</i></li>
#     <li>Activate your virtual environment<br>
#         <i>> source activate HW3</i></li>
#     <li>To install auxiliary libraries, replace the "package_name" in the following command and run it in activated "hw3" environment <br>
#         <i>> pip install "package_name"<i></li>
#      <li>When you create your virtual environment with "anaconda" metapackage, jupyter notebook should be installed. Try:<br>
#          <i>> jupyter notebook</i>
# </ul>
#
#
# #### PyTorch Installation with Anaconda
#
# You should install PyTorch to your virtual environment which is created for the hw3. Therefore, you should activate your homework virtual environment before to start PyTorch installation.
# <li>> source activate HW3</li>
#
# After you have activated the virtual environment, then use one of the following commands to install pytorch for CPU for your system. See https://pytorch.org/ for help.
# <ul>
# <li>For MacOS:<br>
#     <i>> conda install pytorch torchvision -c pytorch</i>
# </li>
# <li>For Linux:<br>
#     <i>> conda install pytorch-cpu torchvision-cpu -c pytorch</i>
# </li>
# <li>For Windows:<br>
#     <i>> conda install pytorch-cpu torchvision-cpu -c pytorch</i><br>
# </li>

# %% [markdown]
# ###Pip3 Installation
# <ul>
#     <li>Download pip3 from https://pip.pypa.io/en/stable/installing/</li>
#     <li>If you are using Windows, you may need to add Python to your enviroment variables. You may use the following tutorial to install Python and pip.
#     https://phoenixnap.com/kb/how-to-install-python-3-windows</li>
# </ul>
#
# #### PyTorch Installation with Pip
# <ul>
# <li>For MacOS:<br>
#     <i>> pip3 install torch torchvision</i>
# </li>
# <li>For Linux:<br>
#     <i>> pip3 install torch==1.3.1+cpu torchvision==0.4.2+cpu -f https://download.pytorch.org/whl/torch_stable.html</i>
# </li>
# <li>For Windows:<br>
#     <i>> pip3 install torch==1.3.1+cpu torchvision==0.4.2+cpu -f https://download.pytorch.org/whl/torch_stable.html</i><br>
# </li>

# %% [markdown]
# # Question 1 [30 pts.]

# %% [markdown]
# Please refer to Q1.pdf for the question.

# %% [markdown]
# # Question 2 [70 pts.]

# %% [markdown]
# Computer vision (CV) is the field of study which deals with how computers can gain high-level understanding from digital images or videos. For this question you will develop neural network models to classify images. You are encouraged to use GPU for model training. Here you will use a subset of Fashion-MNIST dataset for evaluating your networks.
#
# Fashion-MNIST dataset is composed of: (i) a training set of 60,000 images; and (ii) a test set of 10,000 images. These images are grayscale and have a size of 28x28. Each image belongs to one of the following categories: T-shirt/Top (Class 0), Trouser (Class 1), Pullover (Class 2), Dress (Class 3), Coat (Class 4), Sandal (Class 5), Shirt (Class 6), Sneaker (Class 7), Bag (Class 8) and Ankle boot (Class 9). For this question you will use half of the images in the official training set for training and validating your models, which we will refer to as the development dataset. Furthermore, you will evaluate your trained models on the test dataset. Both development and test datasets are provided to you as a pickled Python dictionary in _q2_dataset_. Keys of the dictionary are the following:
# *   *development_x*: 30,000 images for training and validating models.
# *   *development_y*: Class labels for the images in development set.
# *   *test_x*: 10,000 images for testing the models.
# *   *test_y*: Class labels for the images in the test set.
# *   *label2name*: a list whose elements are class names (e.g. Class 0 corresponds to the first element and contains "T-shirt").
#
# Libraries that are required in this question is given in the following code cell.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !ls /content/gdrive/My\ Drive/Dora/Bilkent/CS464/HW3 # Use YOUR OWN DIRECTORY!!

import os
import sys
import pdb
import pickle
from time import time

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torch.autograd import Variable

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
from time import time

import pandas as pd

torch.manual_seed(6)
torch.cuda.manual_seed(6)
np.random.seed(6)

# You could add your own libraries form Python Standard Library in this cell. Any other external libraries are not allowed.
# Out:
# Mounted at /content/gdrive
# breast_cancer.csv  cs464_spring2021_hw3.ipynb  Q1.pdf  q2_dataset

# %% [markdown]
# ### Data Loader [5 pts.]

# %% [markdown]
# An important part of such a task is to implement your own data loader. In this part, you will implement the <b>FashionMNISTDataset</b> class, which inherits from the Dataset class in PyTorch library. This class partially provided to you below.  You need to complete the code below to create your custom <b>FashionMNISTDataset</b> class which will be able to load your dataset. Implement the functions whose prototypes are given. Follow the TODO notes below. You have to divide the development set into <b>training (80%)</b> and <b>validation (20%)</b> sets.  These non-overlapping splits and the test split as well as the list stored at the "label2name" field of the dataset dictionary should be retrieved using the <b>create_dataset</b> function. You should create instances of FashionMNISTDataset for each split.  Since this data loader will be called to get the input for different models, your function should work in a least two modes:
# 1. To be compatible with MLP, you need to flatten the images.
# <br>
# 2. To be compatible with CNN, you need to resize the image to 1x28x28. Note that, you **should not** flatten the image in this mode.
#
# Hint 1: The dataset is not normalized and your results will heavily depend on your input.

# %%
class FashionMNISTDataset(Dataset):
    # TODO:
    """Define constructor for FashionMNISTDataset class
    HINT: You can pass processed data samples and their ground truth values as parameters"""
    def __init__(self, data_samples, data_gtruth, transform = None): # you are free to change parameters
        self.X = np.array(data_samples) #.reshape(-1,1,28,28)
        self.y = np.array(data_gtruth)      
        self.transform = transform;

    '''This function should return sample count in the dataset'''
    def __len__(self):
        return len(self.X)

    '''This function should return a sample and its ground truth value from the dataset corresponding to index parameter '''
    def __getitem__(self, index):
        item = self.X[index];
        label = self.y[index];
        
        if self.transform:
            item = self.transform(item);
        
        return (item, label);

# %%
def normalize(image):
    pixels = np.asarray(image)
    pixels = pixels.astype('float32')
    pixels /= 255.0
    return pixels 


def create_dataset(path_to_dataset_file, mode, filename = 'q2_dataset'):
    # TODO: 
    # Read dataset files using pickle library
    # Construct training, validation and test sets and return them
    
    root = path_to_dataset_file
    q2_pickled = os.path.join(path_to_dataset_file, filename)
    
    infile = open(q2_pickled,'rb')
    database_dict = pickle.load(infile)
    infile.close()
    
    development_X = database_dict['development_X']
    development_y = database_dict['development_y']

    test_X = database_dict['test_X']
    test_y = database_dict['test_y']
    
    X_train, X_vald, y_train, y_vald = train_test_split(development_X, development_y, test_size = 0.2, random_state = 42)

    label2name = database_dict['label2name']
    if mode == 'MLP' :
        X_train = np.array(X_train).reshape(-1, 28*28)
        X_vald = np.array(X_vald).reshape(-1, 28*28)
        test_X = np.array(test_X).reshape(-1, 28*28)

    elif mode == 'CNN' :  
        X_train = np.array(X_train).reshape(-1, 1, 28, 28)
        X_vald = np.array(X_vald).reshape(-1, 1, 28, 28)
        test_X = np.array(test_X).reshape(-1, 1, 28, 28)

    train_dataset = FashionMNISTDataset(X_train, y_train, normalize)
    vald_dataset = FashionMNISTDataset(X_vald, y_vald, normalize)
    test_dataset = FashionMNISTDataset(test_X, test_y, normalize)

    return train_dataset, vald_dataset, test_dataset, label2name

# %% [markdown]
# I added additional codes for seeing the datasets:

# %%
# CNN test

train_dataset, vald_dataset, test_dataset, label2name = create_dataset('/content/gdrive/My Drive/Dora/Bilkent/CS464/HW3', 'CNN')

fig = plt.figure(figsize=(8,8));
columns = 4;
rows = 5;

for i in range(1, columns*rows +1):
    img_xy = np.random.randint(len(train_dataset));
    img = train_dataset[img_xy][0][0,:,:]
    fig.add_subplot(rows, columns, i)
    plt.title(label2name[train_dataset[img_xy][1]])
    plt.axis('off')
    plt.imshow(img, cmap='gray')
    
plt.show()

# %%
 # MLP Test

train_dataset, vald_dataset, test_dataset, label2name = create_dataset('/content/gdrive/My Drive/Dora/Bilkent/CS464/HW3', 'MLP')

fig = plt.figure(figsize=(8,8));
columns = 4;
rows = 5;

for i in range(1, columns*rows +1):
    img_xy = np.random.randint(len(train_dataset));
    img = train_dataset.X[img_xy]
    fig.add_subplot(rows, columns, i)
    plt.title(label2name[train_dataset.y[img_xy]])
    plt.axis('off')
    plt.imshow(img.reshape(28,28), cmap='gray')

plt.show()

# %% [markdown]
# ### Model Implementation [15 pts.]

# %% [markdown]
# #### Multi Layer Perceptron (MLP) [5 pts.]
# Now, implement your three layer neural network (i.e. one input and two hidden layers). MLP class, whose template is given below, will represent your neural network. First and second hidden layers will have 256 and 64 neurons, respectively. You will decide on the number of input and output neurons. Use ReLU as your hidden layer activation function. You need to pick a proper activation function for the output layer and a proper weight initialization scheme for fully-connected layers.

# %%
class MLP(nn.Module):
    '''Define your neural network'''
    def __init__(self, **kwargs): # you can add any additional parameters you want 
        # TODO:
        # You should create your neural network here
        super(MLP, self).__init__()
        self.start = nn.Linear(28*28, 256)
        self.hidden1 = nn.Linear(256, 64)
        self.hidden2 = nn.Linear(64, 32)
        self.out = nn.Linear(32, 10)
    def forward(self, x): # you can add any additional parameters you want
        # TODO:
        # Forward pass implementation should be here
        #x = x.view(-1, 28*28)
        x = self.start(x)
        x = torch.relu(x)
        x = self.hidden1(x)
        x = torch.relu(x)
        x = self.hidden2(x)
        x = torch.relu(x)
        x = self.out(x)      
        return x

# %% [markdown]
# #### Convolutional Neural Network (CNN) [10 pts]
#
# Now implement your convolutional neural network. CNN class, whose template is given below, will represent your convolutional neural network. Your network will have several convolutional layers followed by a fully-connected classification layer. This model utilizes batch normalization which helps to  stabilize the learning process and dramatically reduces the number of training epochs required to train deep networks. You need to choose appropriate input and output neuron sizes, and  activation functions for the fully-connected layers. The architecture can be summarised as follows:
# <ul>
#   <li> 64 filters with size of 2 x 2 with stride 1 and zero padding to both sides, ReLU </li>
#   <li> 2 x 2 max pool. </li>
#   <li> 128 filters with size of 2 x 2 with stride 1 and zero padding to both sides, Batch Normalization, ReLU </li>
#   <li> 2 x 2 max pool. </li>
#   <li> Fully-connected layer </li>
# </ul>

# %%
class CNN(nn.Module):
    '''Define your neural network'''

    def __init__(self, out_1=64, out_2=128,number_of_classes=10):  #No. of classes is 10
        super(CNN, self).__init__()
        self.cnn1 = nn.Conv2d(in_channels=1, out_channels=out_1, kernel_size=2, stride=1, padding=2)
        self.maxpool1=nn.MaxPool2d(kernel_size=2)
        self.cnn2 = nn.Conv2d(in_channels=out_1, out_channels=out_2, kernel_size=2, stride=1, padding=2)
        self.maxpool2=nn.MaxPool2d(kernel_size=2)
        self.fc1 = nn.Linear(out_2 * 9 * 9, number_of_classes)
    
    
    def forward(self, x): # you can add any additional parameters you want
        # TODO:
        # Forward propagation implementation should be here
        x = self.cnn1(x)
        x = torch.relu(x)
        x = self.maxpool1(x)
        x = self.cnn2(x)
        x = torch.relu(x)
        x = self.maxpool2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x

# %% [markdown]
# ### Model Training [20 pts.]

# %% [markdown]
# Train both models for 50 epochs with properly processes inputs (i.e. call create_dataset function in mode "mlp" for MLP model and mode "cnn" for CNN model). Experiment with several optimizers including Stochastic Gradient Descent(SGD), SGD with momentum and Adam. Tune your learning rate. Save your best models (i.e. MLP and CNN models with highest performance) as "best_mlp.pth" and "best_cnn.pth", respectively. You may use any performance metric to compare performance of the models. However, you must explain your reasoning behind selected optimizer and model. During training you are expected to plot two properly formatted figures per model:
# <ol>
# <li>Training and validation losses vs. epochs</li>
# <li>Accuracy calculated on training and validation sets vs. epoch.
# </ol>
#
# Hint 1: Training the models on CPU should not take days. You are encouraged to train the models on GPU (Runtime > Change Runtime Type).
# Hint 2: Select batch size mindfully in order to train the models in a reasonable time.

# %% [markdown]
# #### Train MLP [8 pts]

# %%
# HINT: note that your training time should not take many days. You may consider training on GPU.

# TODO:
# Pick your hyper parameters
max_epoch = 50
train_batch = 10
test_batch = 10
learning_rate = 0.001

best_path_mlp = "/best_mlp.pth"

try:
    os.mkdir(best_path_mlp)
except OSError:
    print ("Creation of the directory %s failed, it might already exist." % best_path_mlp)
else:
    print ("Successfully created the directory %s " % best_path_mlp)

use_gpu = torch.cuda.is_available()

# Create train dataset loader
# Create validation dataset loader
# Create test dataset loader
# initialize your network

if not use_gpu :
    sys.exit('System is not connected to GPU. Please connect GPU and try again.')
else:
    print('GPU connected. Starting Analysis...\n')

model_mlp = MLP().cuda()

train_dataset_MLP, vald_dataset_MLP, test_dataset_MLP, label2name_MLP = create_dataset('/content/gdrive/My Drive/Dora/Bilkent/CS464/HW3', 'MLP')

criterion = nn.CrossEntropyLoss(); # define loss function
optimizer = torch.optim.SGD(model_mlp.parameters(), lr=learning_rate, momentum=0.9); # define optimizer

train_loader_MLP = torch.utils.data.DataLoader(dataset=train_dataset_MLP, batch_size=train_batch, shuffle=True);
vald_loader_MLP = torch.utils.data.DataLoader(dataset=vald_dataset_MLP, batch_size=test_batch, shuffle=True);
test_loader_MLP = torch.utils.data.DataLoader(dataset=test_dataset_MLP, batch_size=test_batch, shuffle=True);

mlp_loss_list = []
mlp_accuracy_list=[]
N_test = len(vald_dataset)
candidate_num = 0
best_epoch = 0

# start training
# for each epoch calculate validation performance
# save best model according to validation performance

for epoch in range(max_epoch):
    model_mlp.train().cuda()
    # iterate over training batches
    for x_train, y_train in train_loader_MLP:
        x_train = Variable(x_train.float()).cuda()
        y_train = Variable(y_train).cuda()

        optimizer.zero_grad()
        z = model_mlp(x_train).cuda()
        loss = criterion(z, y_train)
        loss.backward()
        optimizer.step()

        mlp_loss_list.append(loss.item());
        final_loss = loss.item()
        
    correct=0
    model_mlp.eval()
    # perform a prediction on the validation  data 
    # iterate over validation batches
    with torch.no_grad() :
        for X_vald, y_vald in vald_loader_MLP:
            X_vald = Variable(X_vald.float()).cuda()
            y_vald = Variable(y_vald).cuda()
            z = model_mlp(X_vald)
            _, yhat = torch.max(z.data, 1)
            correct += (yhat == y_vald).sum().item()
         
    accuracy = correct / N_test * 100
    mlp_accuracy_list.append(accuracy)

    if accuracy > mlp_accuracy_list[best_epoch] and accuracy > 84.5 : # condition on accuracy after some testing.
        #print('I found a best model candidate')
        best_epoch = epoch
        torch.save(model_mlp, os.path.basename(best_path_mlp))
        candidate_num += 1
    
    print('.', end= '')
    #print('Epoch Number = ', epoch+1, ', Accuracy =', format(accuracy, ".4f"), ', Loss of Last Iteration =', final_loss)
    

# if there were no epochs in which the conditions are fulfilled, just take the last epoch.
if candidate_num == 0 :
    torch.save(model_mlp, os.path.basename(best_path_mlp))

fig, axis1 = plt.subplots()
loss_in_epochs = mlp_loss_list[0::(len(mlp_loss_list)//max_epoch)]

# plot losses vs epoch 
red = 'tab:red'
axis1.plot(loss_in_epochs, color=red)
axis1.set_xlabel('epoch')
axis1.set_ylabel('loss', color=red)
axis1.set_title('Accuracy and Losses of the MLP Model\nTrained on the Training and Validation Datasets')

# plot accuracies vs epoch        
axis2 = axis1.twinx()  
blue = 'tab:blue'
axis2.set_ylabel('accuracy', color=blue) 
axis2.plot( mlp_accuracy_list, color=blue)

fig.tight_layout()
# Out:
# Creation of the directory /best_mlp.pth failed, it might already exist.
# GPU connected. Starting Analysis...
#
# ..................................................

# %% [markdown]
# #### Train CNN [12 pts]

# %%
# HINT: note that your training time should not take many days. You may consider training on GPU.

# TODO:
# Pick your hyper parameters
max_epoch = 50
train_batch = 10
test_batch = 10
learning_rate = 0.001

use_gpu = torch.cuda.is_available()

best_path_cnn = "/best_cnn.pth"

try:
    os.mkdir(best_path_cnn)
except OSError:
    print ("Creation of the directory %s failed, it might already exist." % best_path_mlp)
else:
    print ("Successfully created the directory %s " % best_path_mlp)

# Create train dataset loader
# Create validation dataset loader
# Create test dataset loader
# initialize your network

if not use_gpu :
    sys.exit('System is not connected to GPU. Please connect GPU and try again.')
else:
    print('GPU connected. Starting Analysis...\n')


model_cnn = CNN().cuda()
train_dataset_CNN, vald_dataset_CNN, test_dataset_CNN, label2name_CNN = create_dataset('/content/gdrive/My Drive/Dora/Bilkent/CS464/HW3','CNN')

criterion = nn.CrossEntropyLoss(); # define loss function
optimizer = torch.optim.SGD(model_cnn.parameters(), lr=learning_rate, momentum= 0.9); # define optimizer

train_loader_CNN = torch.utils.data.DataLoader(dataset=train_dataset_CNN, batch_size=train_batch, shuffle=True);
vald_loader_CNN = torch.utils.data.DataLoader(dataset=vald_dataset_CNN, batch_size=test_batch, shuffle=True);
test_loader_CNN = torch.utils.data.DataLoader(dataset=test_dataset_CNN, batch_size=test_batch, shuffle=True);

cnn_loss_list = []
cnn_accuracy_list=[]
N_test = len(vald_dataset)
candidate_num = 0

# start training
# for each epoch calculate validation performance
# save best model according to validation performance

acc_list = np.array([])
best_epoch = 0

for epoch in range(max_epoch):
    model_cnn.train().cuda()
    # iterate over training batches
    for x_train, y_train in train_loader_CNN:
        x_train = Variable(x_train.float()).cuda()
        y_train = Variable(y_train).cuda()

        optimizer.zero_grad()
        z = model_cnn(x_train).cuda()
        loss = criterion(z, y_train)
        loss.backward()
        optimizer.step()

        cnn_loss_list.append(loss.item());
        final_loss = loss.item()
          
    correct=0
    model_cnn.eval()
    # perform a prediction on the validation  data 
    # iterate over validation batches
    with torch.no_grad() :
        for X_vald, y_vald in vald_loader_CNN:
            X_vald = Variable(X_vald.float()).cuda()
            y_vald = Variable(y_vald).cuda()
            z = model_cnn(X_vald)
            _, yhat = torch.max(z.data, 1)
            correct += (yhat == y_vald).sum().item()
            
    accuracy = correct / N_test * 100
    cnn_accuracy_list.append(accuracy)

    if accuracy > cnn_accuracy_list[best_epoch] and accuracy > 90 : # condition on accuracy after some testing.
        #print('I found a best model candidate')
        best_epoch = epoch
        torch.save(model_cnn, os.path.basename(best_path_cnn))
        candidate_num += 1
    
    print('.', end= '')    
    #print('Epoch Number = ', epoch+1, ', Accuracy =', format(accuracy, ".4f"), '% , Loss of Last Iteration =', final_loss)


# if there were no epochs in which the conditions are fulfilled, just take the last epoch.
if candidate_num == 0 :
    torch.save(model_cnn, os.path.basename(best_path_cnn)) 

fig, axis1 = plt.subplots()
loss_in_epochs = cnn_loss_list[0::(len(cnn_loss_list)//max_epoch)]

# plot losses vs epoch 
red = 'tab:red'
axis1.plot(loss_in_epochs, color=red)
axis1.set_xlabel('epoch')
axis1.set_ylabel('loss', color=red)
axis1.set_title('Accuracy and Losses of the CNN Model\nTrained on the Training and Validation Datasets')

# plot accuracies vs epoch        
axis2 = axis1.twinx()  
blue = 'tab:blue'
axis2.plot( cnn_accuracy_list, color=blue)
axis2.set_ylabel('accuracy', color=blue) 

fig.tight_layout()
# Out:
# Creation of the directory /best_mlp.pth failed, it might already exist.
# GPU connected. Starting Analysis...
#
# ..................................................

# %% [markdown]
# #### **My Answers**

# %% [markdown]
# * I picked the SGD model with momentum = 0.9 for both models. The reason for choosing SGD instead of Adam was that Adam optimizer increases the accuracy at lower epoch number, but after immediately increasing the accuracy, it starts to decline. SGD provided a more stable increase in accuracy. Adding the momentum boosted the accuracy models without the risk of overtting, so this was preffered. I also used accuracy and losses as a metric to evaluate the models. For both models, SGD with momentum gived very pleasing training results.

# %% [markdown]
# ### Model Testing [10 pts]

# %% [markdown]
# Report the following for your best model on your test set which has not been seen by the model yet.
# 1. A heatmap for confusion matrix
# 2. Accuracy
# 3. Accuracy for each class
# 4. Macro Precision
# 5. Macro Recall
# 6. Macro F1 Score
#
# You may plot the heatmap for the confusion matrix using <b>plot_cm</b> function provided below.

# %%
def plot_cm(cm, class_labels):
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=range(len(class_labels)),
           yticks=range(len(class_labels)),
           xticklabels=class_labels, yticklabels=class_labels,
           title="Confusion Matrix",
           ylabel='True label',
           xlabel='Predicted label')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# #### Test MLP [3 pts].

# %%
# TODO: 
# load trained model
# test the model by iterating over test batches
# calculate and print performance metrics
# plot confusion matrix using class names instead of class labels

model_best_mlp = torch.load(os.path.basename(best_path_mlp))
model_best_mlp.eval()

y_true_MLP = np.array([])
y_pred_MLP = np.array([])

for images, labels in test_loader_MLP:
    images = Variable(images.float()).cuda()
    labels = Variable(labels).cuda()
    outputs = model_best_mlp(images)
    _, predicted = torch.max(outputs.data, 1)

    y_true_MLP = np.concatenate((y_true_MLP, labels.cpu().detach().numpy()))
    y_pred_MLP = np.concatenate((y_pred_MLP, predicted.cpu().detach().numpy()))

cm_mlp = confusion_matrix(y_true_MLP, y_pred_MLP)

accuracy_MLP = accuracy_score(y_true_MLP, y_pred_MLP) # normal accuracy
print('Accuracy is equal to', format(accuracy_MLP*100, ".2f"), '%')

#Obtain floats of matrix;
label_matrix_MLP = cm_mlp.astype('float')
#Iterate for each class by finding the confusion matrix results wrt. a single class
for i in range(len(label2name_MLP)):  
    label_tp = label_matrix_MLP[i,i]
    label_fp = label_matrix_MLP[:, i].sum() - label_tp
    label_fn = label_matrix_MLP[i, :].sum() - label_tp
    label_tn = label_matrix_MLP.sum() - label_fp - label_tp - label_fn
    label_accuracy = (label_tp + label_tn)/label_matrix_MLP.sum()
    print('Accuracy for class', label2name_MLP[i], 'is equal to', format(label_accuracy*100, ".2f"), '%')

precision_MLP = precision_score(y_true_MLP, y_pred_MLP, average='macro')
print('Macro Avg. Precision is equal to', format(precision_MLP*100, ".2f"), '%')

recall_MLP = recall_score(y_true_MLP, y_pred_MLP, average='macro')
print('Macro Avg. Recall is equal to', format(recall_MLP*100, ".2f"), '%')

f1_measure_MLP = f1_score(y_true_MLP, y_pred_MLP, average='macro')
print('Macro Avg. F1 Score is equal to', format(f1_measure_MLP*100, ".2f"), '%')

plot_cm(cm_mlp, label2name)
print()
# Out:
# Accuracy is equal to 88.60 %
# Accuracy for class T-shirt is equal to 96.43 %
# Accuracy for class Trouser is equal to 99.63 %
# Accuracy for class Pullover is equal to 96.36 %
# Accuracy for class Dress is equal to 97.94 %
# Accuracy for class Coat is equal to 96.39 %
# Accuracy for class Sandal is equal to 98.94 %
# Accuracy for class Shirt is equal to 94.51 %
# Accuracy for class Sneaker is equal to 98.58 %
# Accuracy for class Bag is equal to 99.31 %
# Accuracy for class Ankle Boot is equal to 99.11 %
# Macro Avg. Precision is equal to 88.68 %
# Macro Avg. Recall is equal to 88.60 %
# Macro Avg. F1 Score is equal to 88.53 %

# %% [markdown]
# #### Test CNN [7 pts]

# %%
# TODO: 
# load trained model
# test the model by iterating over test batches
# calculate and print performance metrics
# plot confusion matrix using class names instead of class labels

model_best_cnn = torch.load(os.path.basename(best_path_cnn))
model_best_cnn.eval()
y_true_CNN = np.array([])
y_pred_CNN = np.array([])

for images, labels in test_loader_CNN:
    images = Variable(images.float()).cuda()
    labels = Variable(labels).cuda()
    outputs = model_best_cnn(images)
    _, predicted = torch.max(outputs.data, 1)

    y_true_CNN = np.concatenate((y_true_CNN, labels.cpu().detach().numpy()))
    y_pred_CNN = np.concatenate((y_pred_CNN, predicted.cpu().detach().numpy()))

cm_cnn = confusion_matrix(y_true_CNN, y_pred_CNN)

accuracy_CNN = accuracy_score(y_true_CNN, y_pred_CNN) # normal accuracy
print('Accuracy is equal to', format(accuracy_CNN*100, ".2f"), '%')

#Obtain floats of matrix;
label_matrix_CNN = cm_cnn.astype('float')
#Iterate for each class by finding the confusion matrix results wrt. a single class
for i in range(len(label2name_CNN)):  
    label_tp = label_matrix_CNN[i,i]
    label_fp = label_matrix_CNN[:, i].sum() - label_tp
    label_fn = label_matrix_CNN[i, :].sum() - label_tp
    label_tn = label_matrix_CNN.sum() - label_fp - label_tp - label_fn
    label_accuracy = (label_tp + label_tn)/label_matrix_CNN.sum()
    print('Accuracy for class', label2name_CNN[i], 'is equal to', format(label_accuracy*100, ".2f"), '%')

precision_CNN = precision_score(y_true_CNN, y_pred_CNN, average='macro')
print('Macro Avg. Precision is equal to', format(precision_CNN*100, ".2f"), '%')

recall_CNN = recall_score(y_true_CNN, y_pred_CNN, average='macro')
print('Macro Avg. Recall is equal to', format(recall_CNN*100, ".2f"), '%')

f1_measure_CNN = f1_score(y_true_CNN, y_pred_CNN, average='macro')
print('Macro Avg. F1 Score is equal to', format(f1_measure_CNN*100, ".2f"), '%')

plot_cm(cm_cnn, label2name)
print()
# Out:
# Accuracy is equal to 91.17 %
# Accuracy for class T-shirt is equal to 97.16 %
# Accuracy for class Trouser is equal to 99.66 %
# Accuracy for class Pullover is equal to 97.44 %
# Accuracy for class Dress is equal to 98.26 %
# Accuracy for class Coat is equal to 97.29 %
# Accuracy for class Sandal is equal to 99.56 %
# Accuracy for class Shirt is equal to 94.80 %
# Accuracy for class Sneaker is equal to 99.18 %
# Accuracy for class Bag is equal to 99.63 %
# Accuracy for class Ankle Boot is equal to 99.36 %
# Macro Avg. Precision is equal to 91.22 %
# Macro Avg. Recall is equal to 91.17 %
# Macro Avg. F1 Score is equal to 91.16 %

# %% [markdown]
# ### Model Comparison [20 pts]
#
# Answer the following questions. Your answers <b>must not exceed 200 words</b> in total. Provide the reasoning for your claims:
# <ul>
# <li> Discuss the figures that you have plotted in <b>Model Training</b> section
# <li> In theory, are both models suitable for processing image data? Discuss. </li>
# <li> Which model performed better on the test set? Do results support your claim for the previous question? Discuss. </li>
# <li> Which measure/metric (among the ones you considered for this question) would you prefer to assess a model trained for multi-class classification task?
# <li> Compare both models in terms of complexity.
# <li> Comment on the inter-class similarity based on your results.
# </ul>

# %% [markdown]
# ***MY ANSWERS:***
#
# * As more epochs are trained, the accuracy of the model increases due to backward propagation, as it passes through many layers.
#
# * In theory,CNN is more suitable for processing images because in CNN, the image is panned. CNN has deeper, partially connected layers and are partially connected unlike the full connection in MLP. Weights in CNN are lower than MLP, whereas MLP weights have redundancy in higher dimensions. However, both can still be used for processing images.
#
# * CNN gave better results than MLP in terms of accuracy, but not by a large difference. Hence both models are suitable for image processing.
#
# * I used Accuracy as a metric for  multi-class classification, because it measures how many correct predictions the model has done out of all predictions. Accuracy is reliable because the dataset is balanced, other metrics other than label accuracies yield similar results.
#
# * In terms of complexity, CNN is more complex because it has deeper connections, has added padding and max pooling, and it does not flatten the images, unlike MLP. This is also observed by the run time difference.
#
# * Both models have difficulty determining the difference between a shirt and a t-shirt. This is expected, as shirts and t-shirts come in many shapes and sizes.
